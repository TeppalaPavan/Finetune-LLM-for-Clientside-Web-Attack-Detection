# %% [markdown]
# # URL Threat Analysis using LangChain + LangGraph
#
# Python 3.11.14 compatible

# %% [markdown]
# ## Install Dependencies
# Run this once

# %%
# !pip install requests python-whois beautifulsoup4 pandas langchain==0.1.16 langgraph==0.0.36 langchain-community==0.0.34 ollama
# Out:
# ^C
# Requirement already satisfied: requests in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.32.5)
# Requirement already satisfied: python-whois in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.9.6)
# Requirement already satisfied: beautifulsoup4 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.14.3)
# Requirement already satisfied: pandas in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.0.0)
# Requirement already satisfied: langchain==0.1.16 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.1.16)
# Requirement already satisfied: langgraph==0.0.36 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.0.36)
# Requirement already satisfied: langchain-community==0.0.34 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.0.34)
# Requirement already satisfied: ollama in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.6.1)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (1.33)
# Collecting langchain-core<0.2.0,>=0.1.42 (from langchain==0.1.16)
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (0.0.2)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.1.16)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (2.12.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain==0.1.16) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.16) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.16) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.16) (3.0.0)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.42->langchain==0.1.16)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (1.0.0)
# Requirement already satisfied: anyio in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (4.12.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.16) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.16) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\ROG\AppData\Roaming\Python\Python311\site-packages (from pydantic<3,>=1->langchain==0.1.16) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.16) (0.4.2)
# Requirement already satisfied: greenlet>=1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.16) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.16) (1.1.0)
# Requirement already satisfied: python-dateutil in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-whois) (2.9.0.post0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: tzdata in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\ROG\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil->python-whois) (1.17.0)
# Using cached langchain_core-0.1.53-py3-none-any.whl (303 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Installing collected packages: packaging, langsmith, langchain-core
#
#   Attempting uninstall: packaging
#
#     Found existing installation: packaging 26.0
#
#     Uninstalling packaging-26.0:
#
#       Successfully uninstalled packaging-26.0
#
#   Attempting uninstall: langsmith
#
#     Found existing installation: langsmith 0.7.6
#
#     Uninstalling langsmith-0.7.6:
#
#       Successfully uninstalled langsmith-0.7.6
#
#    ------------- -------------------------- 1/3 [langsmith]
#   Attempting uninstall: langchain-core
#    ------------- -------------------------- 1/3 [langsmith]
#     Found existing installation: langchain-core 1.2.15
#    ------------- -------------------------- 1/3 [langsmith]
#     Uninstalling langchain-core-1.2.15:
#    ------------- -------------------------- 1/3 [langsmith]
#       Successfully uninstalled langchain-core-1.2.15
#    ------------- -------------------------- 1/3 [langsmith]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    ---------------------------------------- 3/3 [langchain-core]
#
# Successfully installed langchain-core-0.1.53 langsmith-0.1.147 packaging-23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# build 1.4.0 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# langchain-huggingface 1.2.0 requires langchain-core<2.0.0,>=1.2.0, but you have langchain-core 0.1.53 which is incompatible.
# transformers 5.2.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.2 which is incompatible.

# %% [markdown]
# ## Imports

# %%
import requests
import whois
import re
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from typing import TypedDict

# %% [markdown]
# ## Evidence Collection

# %%
import re
import requests
import whois
from bs4 import BeautifulSoup
from urllib.parse import urlparse

def fetch_whois(domain):
    try:
        w = whois.whois(domain)
        return {
            "registrar": getattr(w, "registrar", None),
            "creation_date": str(getattr(w, "creation_date", None)),
            "expiration_date": str(getattr(w, "expiration_date", None)),
            "country": getattr(w, "country", None),
        }
    except Exception as e:
        return {"error": str(e)}

def fetch_headers_from_response(resp):
    h = resp.headers
    return {
        "status": resp.status_code,
        "CSP": h.get("Content-Security-Policy"),
        "XFO": h.get("X-Frame-Options"),
        "HSTS": h.get("Strict-Transport-Security"),
    }

def analyze_html(html):
    soup = BeautifulSoup(html or "", "html.parser")
    return {
        "hidden_forms": len(soup.select("form[style*='display:none']")),
        "password_inputs": len(soup.find_all("input", {"type": "password"})),
        "iframes": len(soup.find_all("iframe")),
    }

def analyze_js(html):
    html = html or ""
    patterns = ["eval(", "document.cookie", "localStorage", "XMLHttpRequest"]
    found = [p for p in patterns if p in html]
    return {
        "dangerous_js": found,
        "obfuscation": bool(re.search(r"[a-zA-Z0-9]{300,}", html)),
    }

def collect_evidence(url):
    if not str(url).startswith(("http://", "https://")):
        url = "http://" + str(url)

    domain = urlparse(url).netloc
    html = ""
    headers = {}
    fetch_error = None

    try:
        resp = requests.get(url, timeout=10, allow_redirects=True)
        html = resp.text
        headers = fetch_headers_from_response(resp)
    except requests.RequestException as e:
        fetch_error = str(e)
        headers = {"error": fetch_error}

    return {
        "whois": fetch_whois(domain),
        "headers": headers,
        "html": analyze_html(html),
        "javascript": analyze_js(html),
        "fetch_error": fetch_error,
    }

# %% [markdown]
# ## LLM + LangGraph

# %%
from langchain_community.llms import Ollama
from langchain.prompts import ChatPromptTemplate
from langgraph.graph import StateGraph, END

llm = Ollama(model="gpt-oss:20b", temperature=0.1)

SYSTEM_PROMPT = '''
Classify URL as SAFE, WARNING or ALERT using evidence only.
Return format:

URL:
FINAL CLASSIFICATION:
CONFIDENCE SCORE:
'''

class State(TypedDict):
    url: str
    evidence: dict
    result: str

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "URL: {url}\nEVIDENCE: {evidence}")
])

def analyze(state: State):
    out = llm.invoke(prompt.format(
        url=state["url"],
        evidence=state["evidence"]
    ))
    return {"result": out}

graph = StateGraph(State)
graph.add_node("analyze", analyze)
graph.set_entry_point("analyze")
graph.add_edge("analyze", END)
app = graph.compile()

# %% [markdown]
# ## Run Dataset

# %%
import pandas as pd

def run(csv_path="url_dataset_safe_warning_alert_200.csv"):
    df = pd.read_csv(csv_path)

    outputs = []
    for _, row in df.iterrows():
        ev = collect_evidence(row["url"])
        res = app.invoke({"url": row["url"], "evidence": ev})
        outputs.append({
            "url": row["url"],
            "ground_truth": row["label"],
            "llm_output": res["result"]
        })
    return outputs
    df = pd.read_csv(url_dataset_safe_warning_alert_200.csv)

# %% [markdown]
# ## Evaluation Metrics

# %%
LABELS = ["SAFE", "WARNING", "ALERT"]

def extract_prediction(text):
    m = re.search(r"(SAFE|WARNING|ALERT)", text)
    return m.group(1) if m else "UNKNOWN"

def confusion_matrix(results):
    cm = pd.DataFrame(0, index=LABELS, columns=LABELS)
    for r in results:
        gt = r["ground_truth"]
        pred = extract_prediction(r["llm_output"])
        if gt in LABELS and pred in LABELS:
            cm.loc[gt, pred] += 1
    return cm

def precision_recall_f1(cm):
    metrics = {}
    for l in LABELS:
        TP = cm.loc[l, l]
        FP = cm[l].sum() - TP
        FN = cm.loc[l].sum() - TP
        p = TP/(TP+FP) if TP+FP else 0
        r = TP/(TP+FN) if TP+FN else 0
        f1 = 2*p*r/(p+r) if p+r else 0
        metrics[l] = {"Precision": p, "Recall": r, "F1": f1}
    return metrics

# %%
results = run("url_dataset_safe_warning_alert_200.csv")
# Out:
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
